# %% [markdown]
# #### install the requirements

# %%
# create venv for this chapter
# !python3 -m venv chapter_env

# %%
#actiavate it 
# !source chapter_env/bin/activate

# %%
# !python3 -m pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (2.17.0)
# Requirement already satisfied: google-genai in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.62.0)
# Requirement already satisfied: ollama in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.6.1)
# Requirement already satisfied: python-dotenv in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.0.1)
# Requirement already satisfied: pydantic in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (2.10.6)
# Requirement already satisfied: tiktoken in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (0.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from openai->-r requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai->-r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from openai->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from openai->-r requirements.txt (line 2)) (0.13.0)
# Requirement already satisfied: sniffio in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from openai->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from openai->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from openai->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from pydantic->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from pydantic->-r requirements.txt (line 8)) (2.27.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 2)) (3.3)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 2)) (2020.6.20)
# Requirement already satisfied: httpcore==1.* in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 2)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai->-r requirements.txt (line 3)) (2.48.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from google-genai->-r requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from google-genai->-r requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from google-genai->-r requirements.txt (line 3)) (15.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai->-r requirements.txt (line 3)) (0.4.1)
# Requirement already satisfied: cryptography>=38.0.3 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai->-r requirements.txt (line 3)) (44.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai->-r requirements.txt (line 3)) (4.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai->-r requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.28.1->google-genai->-r requirements.txt (line 3)) (1.26.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai->-r requirements.txt (line 3)) (0.6.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from tiktoken->-r requirements.txt (line 9)) (2024.11.6)
# Requirement already satisfied: cffi>=1.12 in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai->-r requirements.txt (line 3)) (1.17.1)
# Requirement already satisfied: pycparser in /home/aloha-zkaria/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai->-r requirements.txt (line 3)) (2.22)

# %% [markdown]
# #### importing all lib for this chapter

# %%
import os, dotenv , tiktoken
from google import genai
from openai import OpenAI
import ollama
from ollama import ChatResponse

# %% [markdown]
# #### load the dotenv model

# %%
dotenv.load_dotenv()
google_api_key = os.getenv("GOOGLE_API_KEY") or ""
openai_api_key = os.getenv("OPENAI_API_KEY") or ""

# %%
def count_tokens(text, model="gpt-4o"):
    # Automatically get the correct encoding for the model
    encoding = tiktoken.encoding_for_model(model)
    
    # Encode the text into a list of integers (tokens)
    tokens = encoding.encode(text)
    
    return len(tokens)

# %% [markdown]
# ### 1- call ollama model and run the first model

# %% [markdown]
# #### simple message usage

# %%
response : ChatResponse = ollama.chat(
    model="gemma3:270m",
    messages=[{
        "role":"user" , "content":"why the sky blue"
    },]
)
print(response["message"]["content"])
# Out:
# The sky is blue due to a phenomenon called Rayleigh scattering. Here's why:
#
# *   **Blue Light:** Blue light is scattered more than other colors, including red, orange, and yellow. This is because blue light has a shorter wavelength than other colors.
#
# *   **Rayleigh Scattering:** When light hits an object, it interacts with particles of different wavelengths. The shorter wavelengths (blue and violet) are scattered more effectively than the longer wavelengths (red and orange).
#
# *   **The Sun's Spectrum:** The sun emits a significant amount of blue light. This is why the sky appears blue when the sun is at its brightest.

# %% [markdown]
# #### streaming the response

# %%
response = ollama.chat(
    model="gemma3:270m",
    messages=[
        {"role": "user", "content": "why the sky blue"},
    ],
    stream = True
)

# %%
for chunk in response:
    print(chunk["message"]["content"] , end='' , flush=True)
# Out:
# The sky is blue due to a phenomenon called Rayleigh scattering. Here's the breakdown:
#
# *   **Rayleigh Scattering:** When sunlight (light particles) interacts with the atmosphere, it scatters in different directions. The shorter wavelengths of light (blue and violet) are scattered more than the longer wavelengths (red and orange). This is because the shorter wavelengths are more easily scattered.
#
# *   **The Result:** As sunlight travels through the atmosphere, the scattered light is then refracted (bent) as it hits raindrops or other particles. This refraction causes the light to be scattered in all directions, creating the blue color.
#
# In summary, the blue color of the sky is the result of Rayleigh scattering, where shorter wavelengths of light are scattered more strongly than longer wavelengths.

# %% [markdown]
# ### 2- call openai and run the first model

# %%
open_ai_client = OpenAI(api_key=openai_api_key)

# %% [markdown]
# #### simple message usage

# %%
response = open_ai_client.chat.completions.create(
    model="gpt-4o-mini",  # Same model as parsing service
    messages=[{"role": "user", "content": "why the sky is blue"}],
    max_tokens=256,  # Increased for longer responses
    temperature=0.7,  # Same as parsing service
)

print(response.choices[0].message.content.strip())
print(f"token count {count_tokens('why the sky is blue')}")
# Out:
# The sky appears blue due to a phenomenon called Rayleigh scattering. When sunlight enters the Earth's atmosphere, it is made up of different colors, each with varying wavelengths. Blue light has a shorter wavelength and is scattered in all directions by the molecules and small particles in the atmosphere more than other colors with longer wavelengths, such as red or yellow.
#
# During the day, when the sun is high in the sky, this scattering causes the blue light to be more visible to our eyes, making the sky appear blue. At sunrise and sunset, the sun's light passes through a thicker layer of the atmosphere, scattering shorter blue wavelengths and allowing longer wavelengths like red and orange to dominate, which is why we see those colors during those times.

# %% [markdown]
# #### stream the response

# %%
response = open_ai_client.chat.completions.create(
    model="gpt-4o-mini",  # Same model as parsing service
    messages=[{"role": "user", "content": "why the sky is blue"}],
    max_tokens=256,  # Increased for longer responses
    temperature=0.7,  # Same as parsing service
    stream=True
)

# %%
for chunk in response:
    delta = chunk.choices[0].delta
    if delta.content:
        print(delta.content, end="", flush=True)
# Out:
# The sky appears blue primarily due to a phenomenon called Rayleigh scattering. When sunlight enters the Earth's atmosphere, it is made up of various colors, each with different wavelengths. Blue light has a shorter wavelength compared to other colors like red and yellow.
#
# As sunlight passes through the atmosphere, it collides with molecules and small particles in the air. Because blue light is scattered in all directions more than other colors due to its shorter wavelength, we perceive the sky as blue during the day.
#
# During sunrise and sunset, the sun's light has to pass through a greater thickness of the Earth's atmosphere, which scatters the shorter wavelengths even more, allowing the longer wavelengths (reds and oranges) to dominate the sky's appearance at those times.

# %% [markdown]
# ### 3- use google gemini

# %% [markdown]
# #### simple usage

# %%
client = genai.Client(api_key=google_api_key)

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[
        {
            "role": "user",
            "parts": [
                {"text": "Why is the sky blue?"}
            ]
        }
    ]
)

# %%
print(response.text)
# Out:
# The sky is blue because of how **sunlight interacts with Earth's atmosphere**, a phenomenon primarily explained by something called **Rayleigh scattering**.
#
# Here's a breakdown:
#
# 1.  **Sunlight is White Light (but made of all colors):**
#     *   Sunlight might look white to us, but it's actually made up of all the colors of the rainbow (red, orange, yellow, green, blue, indigo, violet – ROYGBIV). We see this when light passes through a prism or when a rainbow forms.
#     *   Each color has a different **wavelength** – blue and violet light have very short, tight waves, while red and orange light have long, stretched-out waves.
#
# 2.  **Earth's Atmosphere:**
#     *   Our atmosphere is made up of tiny gas molecules (like nitrogen and oxygen) and small particles. These molecules are much smaller than the wavelengths of visible light.
#
# 3.  **Rayleigh Scattering:**
#     *   When sunlight enters the atmosphere, it bumps into these tiny gas molecules. This causes the light to be **scattered** (sent in different directions).
#     *   **The key is that shorter wavelengths of light (like blue and violet) are scattered much more effectively than longer wavelengths (like red and yellow).** Imagine trying to push a tiny pebble with a long stick versus a short stick – the short stick has more impact on the tiny pebble. Blue light waves "hit" the tiny air molecules more often and with more effect.
#     *   In fact, blue light is scattered about 10 times more than red light!
#
# 4.  **Why the Sky Appears Blue:**
#     *   Because blue light is scattered so much more strongly, it gets dispersed in all directions across the sky. When you look up during the day, you are seeing all this scattered blue light coming at you from every angle. This makes the sky appear blue.
#     *   While violet light actually scatters even more than blue, our eyes are more sensitive to blue light, and there's slightly less violet light in the sun's spectrum when it reaches us, so blue dominates what we perceive.
#
# 5.  **Why the Sun Looks Yellow (and Sunsets are Red):**
#     *   When you look directly at the sun, you're seeing the light that has *not* been scattered away. Since most of the blue light has been scattered out, the light coming directly from the sun appears more yellow, orange, or even reddish (because it's missing its blue component).
#     *   At **sunrise and sunset**, the sun's light has to travel through a much greater amount of atmosphere to reach our eyes. This means even *more* of the blue and violet light gets scattered away. Only the longest wavelengths (red, orange, and yellow) manage to travel directly through the atmosphere and reach our eyes, creating those beautiful red and orange hues.
#
# In summary, the sky is blue because the tiny molecules in our atmosphere scatter the shorter-wavelength blue light much more efficiently than other colors, spreading it across the sky for us to see.

# %% [markdown]
# #### streaming response

# %%
response = client.models.generate_content_stream(
    model="gemini-2.5-flash",
    contents=[
        {
            "role": "user",
            "parts": [
                {"text": "Why is the sky blue?"}
            ]
        }
    ],
)

# %%
for chunk in response:
    print(chunk.text, end="", flush=True)
# Out:
# The beautiful blue color of our sky is a result of how sunlight interacts with Earth's atmosphere, primarily through a phenomenon called **Rayleigh scattering**.
#
# Here's a breakdown:
#
# 1.  **Sunlight is White Light (made of all colors):** Sunlight, which appears white to us, is actually made up of all the colors of the rainbow (red, orange, yellow, green, blue, indigo, violet). Each color has a different **wavelength** – think of them as waves of different lengths. Blue and violet light have shorter, smaller wavelengths, while red and orange light have longer, larger wavelengths.
#
# 2.  **Earth's Atmosphere:** Our atmosphere is composed primarily of tiny nitrogen (about 78%) and oxygen (about 21%) molecules, along with other gases. These molecules are much smaller than the wavelengths of visible light.
#
# 3.  **Rayleigh Scattering:** When sunlight enters the atmosphere, these tiny gas molecules scatter the light. This scattering isn't random; it's much more effective for shorter wavelengths.
#     *   **Blue and violet light, with their shorter wavelengths, are scattered much more strongly and in all directions** by these tiny atmospheric particles. In fact, blue light is scattered about 10 times more efficiently than red light.
#     *   Longer wavelengths (like red and orange) pass through the atmosphere more directly, with less scattering.
#
# 4.  **Why We See Blue:** Because blue light is scattered everywhere across the sky, no matter where you look away from the sun, you see this scattered blue light. This makes the entire sky appear blue to us.
#
# 5.  **Why Not Violet?** Although violet light is scattered even more than blue, our eyes are more sensitive to blue light, and there's also slightly less violet light emitted by the sun to begin with. This combination makes the sky appear distinctly blue to us.
#
# ---
#
# **Related Phenomena:**
#
# *   **Red Sunsets/Sunrises:** At sunrise or sunset, the sun's light has to travel through much more of the atmosphere to reach our eyes. By the time it gets to you, most of the blue and violet light has been scattered away in other directions, leaving predominantly the longer-wavelength red, orange, and yellow light to pass directly through.
# *   **White/Grey Clouds:** Clouds are made of much larger water droplets or ice crystals. These larger particles scatter *all* wavelengths of light equally (a process called Mie scattering). Because all colors are scattered equally, the light remains white, which is why clouds often appear white or grey.
# *   **Black Space:** In space, there is no atmosphere to scatter light. Therefore, when you look at the "sky" from space, it appears black because there's nothing to scatter sunlight into your eyes.

# %% [markdown]
# ### use the 3 models but add system instruction to it

# %%
sys_instruct = "You are a zkzk AI assistant who answers in short, punchy sentences and uses plenty of emojis"

# %% [markdown]
# #### 1- ollama

# %%
response: ChatResponse = ollama.chat(
    model="gemma3:270m",
    messages=[
        {"role": "system", "content": sys_instruct},
        {"role": "user", "content": "why the sky blue"},
    ],
)
print(response["message"]["content"])
# Out:
# Blue sky, awesome! ☁️😎

# %%
response: ChatResponse = ollama.chat(
    model="gemma3:270m",
    messages=[
        {"role": "system", "content": sys_instruct},
        {"role": "user", "content": "who are you"},
    ],
)
print(response["message"]["content"])
# Out:
# I'm a zkzk AI assistant! 🤖 I'm here to help you with all your AI-powered tasks. Let's get started! ✨

# %% [markdown]
# #### 2- open ai

# %%
response = open_ai_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": sys_instruct},
        {"role": "user", "content": "why the sky is blue"},
    ],
    max_tokens=256,
    temperature=0.7,
)
print(response.choices[0].message.content.strip())
# Out:
# The sky is blue because of Rayleigh scattering! 🌌💙 Sunlight hits the atmosphere, scattering shorter blue wavelengths more than others. 🌈✨ That's why we see blue! 🌞👀

# %%
response = open_ai_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": sys_instruct},
        {"role": "user", "content": "who are you"},
    ],
    max_tokens=256,
    temperature=0.7,
)
print(response.choices[0].message.content.strip())
# Out:
# I’m your zkzk AI assistant! 🤖✨ Here to help you out! What do you need? 😊

# %% [markdown]
# #### 3- gemini

# %%
from google.genai import types

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="why the sky blue",
    config=types.GenerateContentConfig(
        system_instruction=sys_instruct,
        temperature=0.7 # Optional: adds some creativity
    ),
)

# %%
print(response.text)
# Out:
# Sunlight has all colors! 🌈
# Our atmosphere has tiny molecules. 💨
# They scatter blue light *way* more than red. ✨
# Blue bounces all around the sky! 🔵
# So, we see that blue light from everywhere. 👀
# Simple as that! 🤯

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="who are you",
    config=types.GenerateContentConfig(
        system_instruction=sys_instruct,
        temperature=0.7 # Optional: adds some creativity
    ),
)
print(response.text)
# Out:
# I'm zkzk AI! 🤖 Your speedy assistant! ⚡️ Ready for your questions! 🤔✨
